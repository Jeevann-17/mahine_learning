# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('Nutrition__Physical_Activity__and_Obesity_-_Behavioral_Risk_Factor_Surveillance_System.csv')
df
# Out:
#        YearStart  YearEnd LocationAbbr    LocationDesc  \
# 0           2011     2011           AL         Alabama
# 1           2011     2011           AL         Alabama
# 2           2011     2011           AL         Alabama
# 3           2011     2011           AL         Alabama
# 4           2011     2011           AL         Alabama
# ...          ...      ...          ...             ...
# 53387       2016     2016           VI  Virgin Islands
# 53388       2016     2016           VI  Virgin Islands
# 53389       2016     2016           VI  Virgin Islands
# 53390       2016     2016           VI  Virgin Islands
# 53391       2016     2016           VI  Virgin Islands
#
#                                        Datasource                    Class  \
# 0      Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 1      Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 2      Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 3      Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 4      Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# ...                                           ...                      ...
# 53387  Behavioral Risk Factor Surveillance System        Physical Activity
# 53388  Behavioral Risk Factor Surveillance System        Physical Activity
# 53389  Behavioral Risk Factor Surveillance System        Physical Activity
# 53390  Behavioral Risk Factor Surveillance System        Physical Activity
# 53391  Behavioral Risk Factor Surveillance System        Physical Activity
#
#                               Topic  \
# 0           Obesity / Weight Status
# 1           Obesity / Weight Status
# 2           Obesity / Weight Status
# 3           Obesity / Weight Status
# 4           Obesity / Weight Status
# ...                             ...
# 53387  Physical Activity - Behavior
# 53388  Physical Activity - Behavior
# 53389  Physical Activity - Behavior
# 53390  Physical Activity - Behavior
# 53391  Physical Activity - Behavior
#
#                                                 Question  Data_Value_Unit  \
# 0      Percent of adults aged 18 years and older who ...              NaN
# 1      Percent of adults aged 18 years and older who ...              NaN
# 2      Percent of adults aged 18 years and older who ...              NaN
# 3      Percent of adults aged 18 years and older who ...              NaN
# 4      Percent of adults aged 18 years and older who ...              NaN
# ...                                                  ...              ...
# 53387  Percent of adults who engage in no leisure-tim...              NaN
# 53388  Percent of adults who engage in no leisure-tim...              NaN
# 53389  Percent of adults who engage in no leisure-tim...              NaN
# 53390  Percent of adults who engage in no leisure-tim...              NaN
# 53391  Percent of adults who engage in no leisure-tim...              NaN
#
#       Data_Value_Type  ...                              GeoLocation  ClassID  \
# 0               Value  ...  (32.84057112200048, -86.63186076199969)      OWS
# 1               Value  ...  (32.84057112200048, -86.63186076199969)      OWS
# 2               Value  ...  (32.84057112200048, -86.63186076199969)      OWS
# 3               Value  ...  (32.84057112200048, -86.63186076199969)      OWS
# 4               Value  ...  (32.84057112200048, -86.63186076199969)      OWS
# ...               ...  ...                                      ...      ...
# 53387           Value  ...                  (18.335765, -64.896335)       PA
# 53388           Value  ...                  (18.335765, -64.896335)       PA
# 53389           Value  ...                  (18.335765, -64.896335)       PA
# 53390           Value  ...                  (18.335765, -64.896335)       PA
# 53391           Value  ...                  (18.335765, -64.896335)       PA
#
#       TopicID QuestionID  DataValueTypeID  LocationID  \
# 0        OWS1       Q036            VALUE           1
# 1        OWS1       Q036            VALUE           1
# 2        OWS1       Q036            VALUE           1
# 3        OWS1       Q036            VALUE           1
# 4        OWS1       Q036            VALUE           1
# ...       ...        ...              ...         ...
# 53387     PA1       Q047            VALUE          78
# 53388     PA1       Q047            VALUE          78
# 53389     PA1       Q047            VALUE          78
# 53390     PA1       Q047            VALUE          78
# 53391     PA1       Q047            VALUE          78
#
#        StratificationCategory1                Stratification1  \
# 0                        Total                          Total
# 1                       Gender                           Male
# 2                       Gender                         Female
# 3                    Education          Less than high school
# 4                    Education           High school graduate
# ...                        ...                            ...
# 53387           Race/Ethnicity                          Asian
# 53388           Race/Ethnicity      Hawaiian/Pacific Islander
# 53389           Race/Ethnicity  American Indian/Alaska Native
# 53390           Race/Ethnicity                2 or more races
# 53391           Race/Ethnicity                          Other
#
#       StratificationCategoryId1 StratificationID1
# 0                           OVR           OVERALL
# 1                           GEN              MALE
# 2                           GEN            FEMALE
# 3                           EDU             EDUHS
# 4                           EDU         EDUHSGRAD
# ...                         ...               ...
# 53387                      RACE           RACEASN
# 53388                      RACE           RACEHPI
# 53389                      RACE           RACENAA
# 53390                      RACE         RACE2PLUS
# 53391                      RACE           RACEOTH
#
# [53392 rows x 33 columns]

# %%
print('The dataframe has\n{} rows and\n{} columns'.format(df.shape[0],df.shape[1]))
# Out:
# The dataframe has
# 53392 rows and
# 24 columns

# %%
# First making a copy of the dataframe
df_copy = df.copy()

# %%
df.drop(['LocationAbbr','LocationDesc','GeoLocation','Class','Topic','Question'],axis=1,inplace=True)

# %%
# Lets look into first two columns, first says start year and second says end year
# lets find instances where start is not equal to end.
df[df['YearStart']!=df['YearEnd']]
# Out:
# Empty DataFrame
# Columns: [YearStart, YearEnd, Datasource, Data_Value_Unit, Data_Value_Type, Data_Value, Data_Value_Alt, Data_Value_Footnote_Symbol, Data_Value_Footnote, Low_Confidence_Limit, High_Confidence_Limit , Sample_Size, Total, Age(years), Education, Gender, Income, Race/Ethnicity, ClassID, TopicID, QuestionID, DataValueTypeID, LocationID, StratificationCategory1, Stratification1, StratificationCategoryId1, StratificationID1]
# Index: []
#
# [0 rows x 27 columns]

# %%
df.rename(columns={'YearStart':'Year'},inplace=True)
df.drop(['YearEnd'],axis=1,inplace=True)

# %%
df.Datasource.value_counts()
# Out:
# Behavioral Risk Factor Surveillance System    53392
# Name: Datasource, dtype: int64

# %%
# Since there is a singular value in each rows the column has no need
df.drop(['Datasource'],axis=1,inplace=True)

# %%
df.Data_Value_Unit.notnull().sum()
# Out:
# 0

# %%
df.drop(['Data_Value_Unit'],axis=1,inplace=True)

# %%
df.Data_Value_Type.value_counts()
# Out:
# Value    53392
# Name: Data_Value_Type, dtype: int64

# %%
# Since there is a singular value in each rows the column has no need
df.drop(['Data_Value_Type'],axis=1,inplace=True)
df
# Out:
#        YearStart  YearEnd LocationAbbr    LocationDesc  \
# 0           2011     2011           AL         Alabama
# 1           2011     2011           AL         Alabama
# 2           2011     2011           AL         Alabama
# 3           2011     2011           AL         Alabama
# 4           2011     2011           AL         Alabama
# ...          ...      ...          ...             ...
# 53387       2016     2016           VI  Virgin Islands
# 53388       2016     2016           VI  Virgin Islands
# 53389       2016     2016           VI  Virgin Islands
# 53390       2016     2016           VI  Virgin Islands
# 53391       2016     2016           VI  Virgin Islands
#
#                                        Datasource                    Class  \
# 0      Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 1      Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 2      Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 3      Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 4      Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# ...                                           ...                      ...
# 53387  Behavioral Risk Factor Surveillance System        Physical Activity
# 53388  Behavioral Risk Factor Surveillance System        Physical Activity
# 53389  Behavioral Risk Factor Surveillance System        Physical Activity
# 53390  Behavioral Risk Factor Surveillance System        Physical Activity
# 53391  Behavioral Risk Factor Surveillance System        Physical Activity
#
#                               Topic  \
# 0           Obesity / Weight Status
# 1           Obesity / Weight Status
# 2           Obesity / Weight Status
# 3           Obesity / Weight Status
# 4           Obesity / Weight Status
# ...                             ...
# 53387  Physical Activity - Behavior
# 53388  Physical Activity - Behavior
# 53389  Physical Activity - Behavior
# 53390  Physical Activity - Behavior
# 53391  Physical Activity - Behavior
#
#                                                 Question  Data_Value_Unit  \
# 0      Percent of adults aged 18 years and older who ...              NaN
# 1      Percent of adults aged 18 years and older who ...              NaN
# 2      Percent of adults aged 18 years and older who ...              NaN
# 3      Percent of adults aged 18 years and older who ...              NaN
# 4      Percent of adults aged 18 years and older who ...              NaN
# ...                                                  ...              ...
# 53387  Percent of adults who engage in no leisure-tim...              NaN
# 53388  Percent of adults who engage in no leisure-tim...              NaN
# 53389  Percent of adults who engage in no leisure-tim...              NaN
# 53390  Percent of adults who engage in no leisure-tim...              NaN
# 53391  Percent of adults who engage in no leisure-tim...              NaN
#
#        Data_Value  ...  Income                 Race/Ethnicity  \
# 0            32.0  ...     NaN                            NaN
# 1            32.3  ...     NaN                            NaN
# 2            31.8  ...     NaN                            NaN
# 3            33.6  ...     NaN                            NaN
# 4            32.8  ...     NaN                            NaN
# ...           ...  ...     ...                            ...
# 53387         NaN  ...     NaN                          Asian
# 53388         NaN  ...     NaN      Hawaiian/Pacific Islander
# 53389         NaN  ...     NaN  American Indian/Alaska Native
# 53390         NaN  ...     NaN                2 or more races
# 53391         NaN  ...     NaN                          Other
#
#                                    GeoLocation  ClassID  TopicID  QuestionID  \
# 0      (32.84057112200048, -86.63186076199969)      OWS     OWS1        Q036
# 1      (32.84057112200048, -86.63186076199969)      OWS     OWS1        Q036
# 2      (32.84057112200048, -86.63186076199969)      OWS     OWS1        Q036
# 3      (32.84057112200048, -86.63186076199969)      OWS     OWS1        Q036
# 4      (32.84057112200048, -86.63186076199969)      OWS     OWS1        Q036
# ...                                        ...      ...      ...         ...
# 53387                  (18.335765, -64.896335)       PA      PA1        Q047
# 53388                  (18.335765, -64.896335)       PA      PA1        Q047
# 53389                  (18.335765, -64.896335)       PA      PA1        Q047
# 53390                  (18.335765, -64.896335)       PA      PA1        Q047
# 53391                  (18.335765, -64.896335)       PA      PA1        Q047
#
#       DataValueTypeID LocationID StratificationCategoryId1 StratificationID1
# 0               VALUE          1                       OVR           OVERALL
# 1               VALUE          1                       GEN              MALE
# 2               VALUE          1                       GEN            FEMALE
# 3               VALUE          1                       EDU             EDUHS
# 4               VALUE          1                       EDU         EDUHSGRAD
# ...               ...        ...                       ...               ...
# 53387           VALUE         78                      RACE           RACEASN
# 53388           VALUE         78                      RACE           RACEHPI
# 53389           VALUE         78                      RACE           RACENAA
# 53390           VALUE         78                      RACE         RACE2PLUS
# 53391           VALUE         78                      RACE           RACEOTH
#
# [53392 rows x 30 columns]

# %%
df.Data_Value_Footnote_Symbol.value_counts()
# Out:
# ~    5046
# Name: Data_Value_Footnote_Symbol, dtype: int64

# %%
df.Data_Value_Footnote_Symbol.isnull().sum()
# Out:
# 48346

# %%
df['Data_Value'][df['Data_Value_Footnote_Symbol']=='~'].isnull().sum()
# Out:
# 5046

# %%
df.Data_Value_Footnote.value_counts()
# Out:
# Data not available because sample size is insufficient.                                                                                                   4624
# Data not available because sample size is insufficient.  If data only missing for the confidence interval, the confidence interval was not calculated.     422
# Name: Data_Value_Footnote, dtype: int64

# %%
# Dropping the rows with ~ value in Data_Value_Footote_Symbol
df.drop(df[df['Data_Value_Footnote_Symbol'] == '~'].index,inplace=True)

# %%
# Now the whole columns Data_Value_Footnote_Symbol and Data_Value_Footnote are NaN values we can drop these columns
df.drop(['Data_Value_Footnote_Symbol','Data_Value_Footnote'],axis=1,inplace=True)

# %%
df.DataValueTypeID.value_counts()
# Out:
# VALUE    48346
# Name: DataValueTypeID, dtype: int64

# %%
# Dropping the DataValueTypeID column since it contains single value in all rows
df.drop(['DataValueTypeID'],axis=1,inplace=True)

# %%
df
# Out:
#        YearStart  YearEnd LocationAbbr    LocationDesc  \
# 0           2011     2011           AL         Alabama
# 1           2011     2011           AL         Alabama
# 2           2011     2011           AL         Alabama
# 3           2011     2011           AL         Alabama
# 4           2011     2011           AL         Alabama
# ...          ...      ...          ...             ...
# 53382       2016     2016           VI  Virgin Islands
# 53383       2016     2016           VI  Virgin Islands
# 53384       2016     2016           VI  Virgin Islands
# 53385       2016     2016           VI  Virgin Islands
# 53386       2016     2016           VI  Virgin Islands
#
#                                        Datasource                    Class  \
# 0      Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 1      Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 2      Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 3      Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 4      Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# ...                                           ...                      ...
# 53382  Behavioral Risk Factor Surveillance System        Physical Activity
# 53383  Behavioral Risk Factor Surveillance System        Physical Activity
# 53384  Behavioral Risk Factor Surveillance System        Physical Activity
# 53385  Behavioral Risk Factor Surveillance System        Physical Activity
# 53386  Behavioral Risk Factor Surveillance System        Physical Activity
#
#                               Topic  \
# 0           Obesity / Weight Status
# 1           Obesity / Weight Status
# 2           Obesity / Weight Status
# 3           Obesity / Weight Status
# 4           Obesity / Weight Status
# ...                             ...
# 53382  Physical Activity - Behavior
# 53383  Physical Activity - Behavior
# 53384  Physical Activity - Behavior
# 53385  Physical Activity - Behavior
# 53386  Physical Activity - Behavior
#
#                                                 Question  Data_Value_Unit  \
# 0      Percent of adults aged 18 years and older who ...              NaN
# 1      Percent of adults aged 18 years and older who ...              NaN
# 2      Percent of adults aged 18 years and older who ...              NaN
# 3      Percent of adults aged 18 years and older who ...              NaN
# 4      Percent of adults aged 18 years and older who ...              NaN
# ...                                                  ...              ...
# 53382  Percent of adults who engage in no leisure-tim...              NaN
# 53383  Percent of adults who engage in no leisure-tim...              NaN
# 53384  Percent of adults who engage in no leisure-tim...              NaN
# 53385  Percent of adults who engage in no leisure-tim...              NaN
# 53386  Percent of adults who engage in no leisure-tim...              NaN
#
#        Data_Value  ...  Gender              Income      Race/Ethnicity  \
# 0            32.0  ...     NaN                 NaN                 NaN
# 1            32.3  ...    Male                 NaN                 NaN
# 2            31.8  ...  Female                 NaN                 NaN
# 3            33.6  ...     NaN                 NaN                 NaN
# 4            32.8  ...     NaN                 NaN                 NaN
# ...           ...  ...     ...                 ...                 ...
# 53382        13.3  ...     NaN  $75,000 or greater                 NaN
# 53383        25.3  ...     NaN   Data not reported                 NaN
# 53384        18.3  ...     NaN                 NaN  Non-Hispanic White
# 53385        24.1  ...     NaN                 NaN  Non-Hispanic Black
# 53386        30.3  ...     NaN                 NaN            Hispanic
#
#                                    GeoLocation ClassID TopicID QuestionID  \
# 0      (32.84057112200048, -86.63186076199969)     OWS    OWS1       Q036
# 1      (32.84057112200048, -86.63186076199969)     OWS    OWS1       Q036
# 2      (32.84057112200048, -86.63186076199969)     OWS    OWS1       Q036
# 3      (32.84057112200048, -86.63186076199969)     OWS    OWS1       Q036
# 4      (32.84057112200048, -86.63186076199969)     OWS    OWS1       Q036
# ...                                        ...     ...     ...        ...
# 53382                  (18.335765, -64.896335)      PA     PA1       Q047
# 53383                  (18.335765, -64.896335)      PA     PA1       Q047
# 53384                  (18.335765, -64.896335)      PA     PA1       Q047
# 53385                  (18.335765, -64.896335)      PA     PA1       Q047
# 53386                  (18.335765, -64.896335)      PA     PA1       Q047
#
#       LocationID StratificationCategoryId1 StratificationID1
# 0              1                       OVR           OVERALL
# 1              1                       GEN              MALE
# 2              1                       GEN            FEMALE
# 3              1                       EDU             EDUHS
# 4              1                       EDU         EDUHSGRAD
# ...          ...                       ...               ...
# 53382         78                       INC         INC75PLUS
# 53383         78                       INC             INCNR
# 53384         78                      RACE           RACEWHT
# 53385         78                      RACE           RACEBLK
# 53386         78                      RACE           RACEHIS
#
# [48346 rows x 27 columns]

# %%
# Dropping the unnecessary column
df.drop(['StratificationCategory1','Stratification1'],axis=1,inplace=True)
df
# Out:
#        YearStart  YearEnd LocationAbbr    LocationDesc  \
# 0           2011     2011           AL         Alabama
# 1           2011     2011           AL         Alabama
# 2           2011     2011           AL         Alabama
# 3           2011     2011           AL         Alabama
# 4           2011     2011           AL         Alabama
# ...          ...      ...          ...             ...
# 53387       2016     2016           VI  Virgin Islands
# 53388       2016     2016           VI  Virgin Islands
# 53389       2016     2016           VI  Virgin Islands
# 53390       2016     2016           VI  Virgin Islands
# 53391       2016     2016           VI  Virgin Islands
#
#                                        Datasource                    Class  \
# 0      Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 1      Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 2      Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 3      Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 4      Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# ...                                           ...                      ...
# 53387  Behavioral Risk Factor Surveillance System        Physical Activity
# 53388  Behavioral Risk Factor Surveillance System        Physical Activity
# 53389  Behavioral Risk Factor Surveillance System        Physical Activity
# 53390  Behavioral Risk Factor Surveillance System        Physical Activity
# 53391  Behavioral Risk Factor Surveillance System        Physical Activity
#
#                               Topic  \
# 0           Obesity / Weight Status
# 1           Obesity / Weight Status
# 2           Obesity / Weight Status
# 3           Obesity / Weight Status
# 4           Obesity / Weight Status
# ...                             ...
# 53387  Physical Activity - Behavior
# 53388  Physical Activity - Behavior
# 53389  Physical Activity - Behavior
# 53390  Physical Activity - Behavior
# 53391  Physical Activity - Behavior
#
#                                                 Question  Data_Value_Unit  \
# 0      Percent of adults aged 18 years and older who ...              NaN
# 1      Percent of adults aged 18 years and older who ...              NaN
# 2      Percent of adults aged 18 years and older who ...              NaN
# 3      Percent of adults aged 18 years and older who ...              NaN
# 4      Percent of adults aged 18 years and older who ...              NaN
# ...                                                  ...              ...
# 53387  Percent of adults who engage in no leisure-tim...              NaN
# 53388  Percent of adults who engage in no leisure-tim...              NaN
# 53389  Percent of adults who engage in no leisure-tim...              NaN
# 53390  Percent of adults who engage in no leisure-tim...              NaN
# 53391  Percent of adults who engage in no leisure-tim...              NaN
#
#       Data_Value_Type  ...  Income                 Race/Ethnicity  \
# 0               Value  ...     NaN                            NaN
# 1               Value  ...     NaN                            NaN
# 2               Value  ...     NaN                            NaN
# 3               Value  ...     NaN                            NaN
# 4               Value  ...     NaN                            NaN
# ...               ...  ...     ...                            ...
# 53387           Value  ...     NaN                          Asian
# 53388           Value  ...     NaN      Hawaiian/Pacific Islander
# 53389           Value  ...     NaN  American Indian/Alaska Native
# 53390           Value  ...     NaN                2 or more races
# 53391           Value  ...     NaN                          Other
#
#                                    GeoLocation ClassID  TopicID  QuestionID  \
# 0      (32.84057112200048, -86.63186076199969)     OWS     OWS1        Q036
# 1      (32.84057112200048, -86.63186076199969)     OWS     OWS1        Q036
# 2      (32.84057112200048, -86.63186076199969)     OWS     OWS1        Q036
# 3      (32.84057112200048, -86.63186076199969)     OWS     OWS1        Q036
# 4      (32.84057112200048, -86.63186076199969)     OWS     OWS1        Q036
# ...                                        ...     ...      ...         ...
# 53387                  (18.335765, -64.896335)      PA      PA1        Q047
# 53388                  (18.335765, -64.896335)      PA      PA1        Q047
# 53389                  (18.335765, -64.896335)      PA      PA1        Q047
# 53390                  (18.335765, -64.896335)      PA      PA1        Q047
# 53391                  (18.335765, -64.896335)      PA      PA1        Q047
#
#        DataValueTypeID LocationID StratificationCategoryId1 StratificationID1
# 0                VALUE          1                       OVR           OVERALL
# 1                VALUE          1                       GEN              MALE
# 2                VALUE          1                       GEN            FEMALE
# 3                VALUE          1                       EDU             EDUHS
# 4                VALUE          1                       EDU         EDUHSGRAD
# ...                ...        ...                       ...               ...
# 53387            VALUE         78                      RACE           RACEASN
# 53388            VALUE         78                      RACE           RACEHPI
# 53389            VALUE         78                      RACE           RACENAA
# 53390            VALUE         78                      RACE         RACE2PLUS
# 53391            VALUE         78                      RACE           RACEOTH
#
# [53392 rows x 31 columns]

# %%
df.Total.value_counts()
# Out:
# Total    1907
# Name: Total, dtype: int64

# %%
df.StratificationCategoryId1.value_counts()
# Out:
# RACE     15256
# INC      13349
# AGEYR    11438
# EDU       7628
# GEN       3814
# OVR       1907
# Name: StratificationCategoryId1, dtype: int64

# %%
df.drop(['Total','Age(years)','Education','Gender','Income','Race/Ethnicity'],axis=1,inplace=True)

# %%
df
# Out:
#        YearStart  YearEnd LocationAbbr    LocationDesc  \
# 0           2011     2011           AL         Alabama
# 1           2011     2011           AL         Alabama
# 2           2011     2011           AL         Alabama
# 3           2011     2011           AL         Alabama
# 4           2011     2011           AL         Alabama
# ...          ...      ...          ...             ...
# 53387       2016     2016           VI  Virgin Islands
# 53388       2016     2016           VI  Virgin Islands
# 53389       2016     2016           VI  Virgin Islands
# 53390       2016     2016           VI  Virgin Islands
# 53391       2016     2016           VI  Virgin Islands
#
#                                        Datasource                    Class  \
# 0      Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 1      Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 2      Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 3      Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 4      Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# ...                                           ...                      ...
# 53387  Behavioral Risk Factor Surveillance System        Physical Activity
# 53388  Behavioral Risk Factor Surveillance System        Physical Activity
# 53389  Behavioral Risk Factor Surveillance System        Physical Activity
# 53390  Behavioral Risk Factor Surveillance System        Physical Activity
# 53391  Behavioral Risk Factor Surveillance System        Physical Activity
#
#                               Topic  \
# 0           Obesity / Weight Status
# 1           Obesity / Weight Status
# 2           Obesity / Weight Status
# 3           Obesity / Weight Status
# 4           Obesity / Weight Status
# ...                             ...
# 53387  Physical Activity - Behavior
# 53388  Physical Activity - Behavior
# 53389  Physical Activity - Behavior
# 53390  Physical Activity - Behavior
# 53391  Physical Activity - Behavior
#
#                                                 Question  Data_Value_Unit  \
# 0      Percent of adults aged 18 years and older who ...              NaN
# 1      Percent of adults aged 18 years and older who ...              NaN
# 2      Percent of adults aged 18 years and older who ...              NaN
# 3      Percent of adults aged 18 years and older who ...              NaN
# 4      Percent of adults aged 18 years and older who ...              NaN
# ...                                                  ...              ...
# 53387  Percent of adults who engage in no leisure-tim...              NaN
# 53388  Percent of adults who engage in no leisure-tim...              NaN
# 53389  Percent of adults who engage in no leisure-tim...              NaN
# 53390  Percent of adults who engage in no leisure-tim...              NaN
# 53391  Percent of adults who engage in no leisure-tim...              NaN
#
#       Data_Value_Type  ...  High_Confidence_Limit   Sample_Size  \
# 0               Value  ...                    33.5       7304.0
# 1               Value  ...                    34.7       2581.0
# 2               Value  ...                    33.6       4723.0
# 3               Value  ...                    37.6       1153.0
# 4               Value  ...                    35.6       2402.0
# ...               ...  ...                     ...          ...
# 53387           Value  ...                     NaN          NaN
# 53388           Value  ...                     NaN          NaN
# 53389           Value  ...                     NaN          NaN
# 53390           Value  ...                     NaN          NaN
# 53391           Value  ...                     NaN          NaN
#
#                                    GeoLocation ClassID  TopicID  QuestionID  \
# 0      (32.84057112200048, -86.63186076199969)     OWS     OWS1        Q036
# 1      (32.84057112200048, -86.63186076199969)     OWS     OWS1        Q036
# 2      (32.84057112200048, -86.63186076199969)     OWS     OWS1        Q036
# 3      (32.84057112200048, -86.63186076199969)     OWS     OWS1        Q036
# 4      (32.84057112200048, -86.63186076199969)     OWS     OWS1        Q036
# ...                                        ...     ...      ...         ...
# 53387                  (18.335765, -64.896335)      PA      PA1        Q047
# 53388                  (18.335765, -64.896335)      PA      PA1        Q047
# 53389                  (18.335765, -64.896335)      PA      PA1        Q047
# 53390                  (18.335765, -64.896335)      PA      PA1        Q047
# 53391                  (18.335765, -64.896335)      PA      PA1        Q047
#
#        DataValueTypeID LocationID StratificationCategoryId1 StratificationID1
# 0                VALUE          1                       OVR           OVERALL
# 1                VALUE          1                       GEN              MALE
# 2                VALUE          1                       GEN            FEMALE
# 3                VALUE          1                       EDU             EDUHS
# 4                VALUE          1                       EDU         EDUHSGRAD
# ...                ...        ...                       ...               ...
# 53387            VALUE         78                      RACE           RACEASN
# 53388            VALUE         78                      RACE           RACEHPI
# 53389            VALUE         78                      RACE           RACENAA
# 53390            VALUE         78                      RACE         RACE2PLUS
# 53391            VALUE         78                      RACE           RACEOTH
#
# [53392 rows x 25 columns]

# %%
# Comparing the Data_Value and Data_Value_Alt columns
df[df['Data_Value']!=df['Data_Value_Alt']]
# Out:
#        YearStart  YearEnd LocationAbbr    LocationDesc  \
# 23          2011     2011           AL         Alabama
# 24          2011     2011           AL         Alabama
# 27          2011     2011           AL         Alabama
# 51          2011     2011           AL         Alabama
# 52          2011     2011           AL         Alabama
# ...          ...      ...          ...             ...
# 53387       2016     2016           VI  Virgin Islands
# 53388       2016     2016           VI  Virgin Islands
# 53389       2016     2016           VI  Virgin Islands
# 53390       2016     2016           VI  Virgin Islands
# 53391       2016     2016           VI  Virgin Islands
#
#                                        Datasource                    Class  \
# 23     Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 24     Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 27     Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 51     Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 52     Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# ...                                           ...                      ...
# 53387  Behavioral Risk Factor Surveillance System        Physical Activity
# 53388  Behavioral Risk Factor Surveillance System        Physical Activity
# 53389  Behavioral Risk Factor Surveillance System        Physical Activity
# 53390  Behavioral Risk Factor Surveillance System        Physical Activity
# 53391  Behavioral Risk Factor Surveillance System        Physical Activity
#
#                               Topic  \
# 23          Obesity / Weight Status
# 24          Obesity / Weight Status
# 27          Obesity / Weight Status
# 51          Obesity / Weight Status
# 52          Obesity / Weight Status
# ...                             ...
# 53387  Physical Activity - Behavior
# 53388  Physical Activity - Behavior
# 53389  Physical Activity - Behavior
# 53390  Physical Activity - Behavior
# 53391  Physical Activity - Behavior
#
#                                                 Question  Data_Value_Unit  \
# 23     Percent of adults aged 18 years and older who ...              NaN
# 24     Percent of adults aged 18 years and older who ...              NaN
# 27     Percent of adults aged 18 years and older who ...              NaN
# 51     Percent of adults aged 18 years and older who ...              NaN
# 52     Percent of adults aged 18 years and older who ...              NaN
# ...                                                  ...              ...
# 53387  Percent of adults who engage in no leisure-tim...              NaN
# 53388  Percent of adults who engage in no leisure-tim...              NaN
# 53389  Percent of adults who engage in no leisure-tim...              NaN
# 53390  Percent of adults who engage in no leisure-tim...              NaN
# 53391  Percent of adults who engage in no leisure-tim...              NaN
#
#       Data_Value_Type  ...                              GeoLocation  ClassID  \
# 23              Value  ...  (32.84057112200048, -86.63186076199969)      OWS
# 24              Value  ...  (32.84057112200048, -86.63186076199969)      OWS
# 27              Value  ...  (32.84057112200048, -86.63186076199969)      OWS
# 51              Value  ...  (32.84057112200048, -86.63186076199969)      OWS
# 52              Value  ...  (32.84057112200048, -86.63186076199969)      OWS
# ...               ...  ...                                      ...      ...
# 53387           Value  ...                  (18.335765, -64.896335)       PA
# 53388           Value  ...                  (18.335765, -64.896335)       PA
# 53389           Value  ...                  (18.335765, -64.896335)       PA
# 53390           Value  ...                  (18.335765, -64.896335)       PA
# 53391           Value  ...                  (18.335765, -64.896335)       PA
#
#       TopicID QuestionID  DataValueTypeID  LocationID  \
# 23       OWS1       Q036            VALUE           1
# 24       OWS1       Q036            VALUE           1
# 27       OWS1       Q036            VALUE           1
# 51       OWS1       Q037            VALUE           1
# 52       OWS1       Q037            VALUE           1
# ...       ...        ...              ...         ...
# 53387     PA1       Q047            VALUE          78
# 53388     PA1       Q047            VALUE          78
# 53389     PA1       Q047            VALUE          78
# 53390     PA1       Q047            VALUE          78
# 53391     PA1       Q047            VALUE          78
#
#        StratificationCategory1                Stratification1  \
# 23              Race/Ethnicity                          Asian
# 24              Race/Ethnicity      Hawaiian/Pacific Islander
# 27              Race/Ethnicity                          Other
# 51              Race/Ethnicity                          Asian
# 52              Race/Ethnicity      Hawaiian/Pacific Islander
# ...                        ...                            ...
# 53387           Race/Ethnicity                          Asian
# 53388           Race/Ethnicity      Hawaiian/Pacific Islander
# 53389           Race/Ethnicity  American Indian/Alaska Native
# 53390           Race/Ethnicity                2 or more races
# 53391           Race/Ethnicity                          Other
#
#       StratificationCategoryId1 StratificationID1
# 23                         RACE           RACEASN
# 24                         RACE           RACEHPI
# 27                         RACE           RACEOTH
# 51                         RACE           RACEASN
# 52                         RACE           RACEHPI
# ...                         ...               ...
# 53387                      RACE           RACEASN
# 53388                      RACE           RACEHPI
# 53389                      RACE           RACENAA
# 53390                      RACE         RACE2PLUS
# 53391                      RACE           RACEOTH
#
# [5046 rows x 33 columns]

# %%
# All the values are same so dropping Data_Value_Alt column
df.drop(['Data_Value_Alt'],axis=1,inplace=True)

# %%
# Checking for null values
df.isnull().sum()
# Out:
# YearStart                         0
# YearEnd                           0
# LocationAbbr                      0
# LocationDesc                      0
# Datasource                        0
# Class                             0
# Topic                             0
# Question                          0
# Data_Value_Unit               53392
# Data_Value_Type                   0
# Data_Value                     5046
# Data_Value_Footnote_Symbol    48346
# Data_Value_Footnote           48346
# Low_Confidence_Limit           5046
# High_Confidence_Limit          5046
# Sample_Size                    5046
# GeoLocation                    1008
# ClassID                           0
# TopicID                           0
# QuestionID                        0
# DataValueTypeID                   0
# LocationID                        0
# StratificationCategoryId1         0
# StratificationID1                 0
# dtype: int64

# %%
# Lets look at ClassID and its meaning in data
df.ClassID.value_counts()
# Out:
# PA     26628
# OWS    17920
# FV      8844
# Name: ClassID, dtype: int64

# %%
df.drop(df[df['ClassID'] != 'OWS'].index,inplace=True)

# %%
df.TopicID.value_counts()
# Out:
# OWS1    17920
# Name: TopicID, dtype: int64

# %%
df.drop(['ClassID','TopicID'],axis=1,inplace=True)

# %%
df
# Out:
#        YearStart  YearEnd LocationAbbr    LocationDesc  \
# 0           2011     2011           AL         Alabama
# 1           2011     2011           AL         Alabama
# 2           2011     2011           AL         Alabama
# 3           2011     2011           AL         Alabama
# 4           2011     2011           AL         Alabama
# ...          ...      ...          ...             ...
# 53387       2016     2016           VI  Virgin Islands
# 53388       2016     2016           VI  Virgin Islands
# 53389       2016     2016           VI  Virgin Islands
# 53390       2016     2016           VI  Virgin Islands
# 53391       2016     2016           VI  Virgin Islands
#
#                                        Datasource                    Class  \
# 0      Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 1      Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 2      Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 3      Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 4      Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# ...                                           ...                      ...
# 53387  Behavioral Risk Factor Surveillance System        Physical Activity
# 53388  Behavioral Risk Factor Surveillance System        Physical Activity
# 53389  Behavioral Risk Factor Surveillance System        Physical Activity
# 53390  Behavioral Risk Factor Surveillance System        Physical Activity
# 53391  Behavioral Risk Factor Surveillance System        Physical Activity
#
#                               Topic  \
# 0           Obesity / Weight Status
# 1           Obesity / Weight Status
# 2           Obesity / Weight Status
# 3           Obesity / Weight Status
# 4           Obesity / Weight Status
# ...                             ...
# 53387  Physical Activity - Behavior
# 53388  Physical Activity - Behavior
# 53389  Physical Activity - Behavior
# 53390  Physical Activity - Behavior
# 53391  Physical Activity - Behavior
#
#                                                 Question  Data_Value_Unit  \
# 0      Percent of adults aged 18 years and older who ...              NaN
# 1      Percent of adults aged 18 years and older who ...              NaN
# 2      Percent of adults aged 18 years and older who ...              NaN
# 3      Percent of adults aged 18 years and older who ...              NaN
# 4      Percent of adults aged 18 years and older who ...              NaN
# ...                                                  ...              ...
# 53387  Percent of adults who engage in no leisure-tim...              NaN
# 53388  Percent of adults who engage in no leisure-tim...              NaN
# 53389  Percent of adults who engage in no leisure-tim...              NaN
# 53390  Percent of adults who engage in no leisure-tim...              NaN
# 53391  Percent of adults who engage in no leisure-tim...              NaN
#
#       Data_Value_Type  ...  Income                 Race/Ethnicity  \
# 0               Value  ...     NaN                            NaN
# 1               Value  ...     NaN                            NaN
# 2               Value  ...     NaN                            NaN
# 3               Value  ...     NaN                            NaN
# 4               Value  ...     NaN                            NaN
# ...               ...  ...     ...                            ...
# 53387           Value  ...     NaN                          Asian
# 53388           Value  ...     NaN      Hawaiian/Pacific Islander
# 53389           Value  ...     NaN  American Indian/Alaska Native
# 53390           Value  ...     NaN                2 or more races
# 53391           Value  ...     NaN                          Other
#
#                                    GeoLocation QuestionID  DataValueTypeID  \
# 0      (32.84057112200048, -86.63186076199969)       Q036            VALUE
# 1      (32.84057112200048, -86.63186076199969)       Q036            VALUE
# 2      (32.84057112200048, -86.63186076199969)       Q036            VALUE
# 3      (32.84057112200048, -86.63186076199969)       Q036            VALUE
# 4      (32.84057112200048, -86.63186076199969)       Q036            VALUE
# ...                                        ...        ...              ...
# 53387                  (18.335765, -64.896335)       Q047            VALUE
# 53388                  (18.335765, -64.896335)       Q047            VALUE
# 53389                  (18.335765, -64.896335)       Q047            VALUE
# 53390                  (18.335765, -64.896335)       Q047            VALUE
# 53391                  (18.335765, -64.896335)       Q047            VALUE
#
#        LocationID  StratificationCategory1                Stratification1  \
# 0               1                    Total                          Total
# 1               1                   Gender                           Male
# 2               1                   Gender                         Female
# 3               1                Education          Less than high school
# 4               1                Education           High school graduate
# ...           ...                      ...                            ...
# 53387          78           Race/Ethnicity                          Asian
# 53388          78           Race/Ethnicity      Hawaiian/Pacific Islander
# 53389          78           Race/Ethnicity  American Indian/Alaska Native
# 53390          78           Race/Ethnicity                2 or more races
# 53391          78           Race/Ethnicity                          Other
#
#       StratificationCategoryId1 StratificationID1
# 0                           OVR           OVERALL
# 1                           GEN              MALE
# 2                           GEN            FEMALE
# 3                           EDU             EDUHS
# 4                           EDU         EDUHSGRAD
# ...                         ...               ...
# 53387                      RACE           RACEASN
# 53388                      RACE           RACEHPI
# 53389                      RACE           RACENAA
# 53390                      RACE         RACE2PLUS
# 53391                      RACE           RACEOTH
#
# [53392 rows x 31 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53392 entries, 0 to 53391
# Data columns (total 31 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   YearStart                   53392 non-null  int64
#  1   YearEnd                     53392 non-null  int64
#  2   LocationAbbr                53392 non-null  object
#  3   LocationDesc                53392 non-null  object
#  4   Datasource                  53392 non-null  object
#  5   Class                       53392 non-null  object
#  6   Topic                       53392 non-null  object
#  7   Question                    53392 non-null  object
#  8   Data_Value_Unit             0 non-null      float64
#  9   Data_Value_Type             53392 non-null  object
#  10  Data_Value                  48346 non-null  float64
#  11  Data_Value_Alt              48346 non-null  float64
#  12  Data_Value_Footnote_Symbol  5046 non-null   object
#  13  Data_Value_Footnote         5046 non-null   object
#  14  Low_Confidence_Limit        48346 non-null  float64
#  15  High_Confidence_Limit       48346 non-null  float64
#  16  Sample_Size                 48346 non-null  float64
#  17  Total                       1907 non-null   object
#  18  Age(years)                  11438 non-null  object
#  19  Education                   7628 non-null   object
#  20  Gender                      3814 non-null   object
#  21  Income                      13349 non-null  object
#  22  Race/Ethnicity              15256 non-null  object
#  23  GeoLocation                 52384 non-null  object
#  24  QuestionID                  53392 non-null  object
#  25  DataValueTypeID             53392 non-null  object
#  26  LocationID                  53392 non-null  int64
#  27  StratificationCategory1     53392 non-null  object
#  28  Stratification1             53392 non-null  object
#  29  StratificationCategoryId1   53392 non-null  object
#  30  StratificationID1           53392 non-null  object
# dtypes: float64(6), int64(3), object(22)
# memory usage: 12.6+ MB

# %%
df['LocationID'] = df.LocationID.astype('object')

# %%
df.describe()
# Out:
#           YearStart       YearEnd  Data_Value_Unit    Data_Value  \
# count  53392.000000  53392.000000              0.0  48346.000000
# mean    2013.281465   2013.281465              NaN     31.156681
# std        1.693300      1.693300              NaN     10.247033
# min     2011.000000   2011.000000              NaN      0.900000
# 25%     2012.000000   2012.000000              NaN     24.100000
# 50%     2013.000000   2013.000000              NaN     30.700000
# 75%     2015.000000   2015.000000              NaN     37.000000
# max     2016.000000   2016.000000              NaN     77.600000
#
#        Data_Value_Alt  Low_Confidence_Limit  High_Confidence_Limit   \
# count    48346.000000          48346.000000            48346.000000
# mean        31.156681             26.892227               35.989997
# std         10.247033             10.038584               11.205813
# min          0.900000              0.300000                3.000000
# 25%         24.100000             20.000000               28.200000
# 50%         30.700000             26.450000               35.600000
# 75%         37.000000             32.900000               42.200000
# max         77.600000             69.500000               87.700000
#
#         Sample_Size    LocationID
# count   48346.00000  53392.000000
# mean     3889.19286     30.282215
# std     19829.42129     16.821318
# min        50.00000      1.000000
# 25%       566.00000     17.000000
# 50%      1209.00000     30.000000
# 75%      2519.00000     44.000000
# max    476876.00000     78.000000

# %%
df.reset_index(drop=True,inplace=True)

# %%
sns.pairplot(df)

# %%
df
# Out:
#        YearStart  YearEnd LocationAbbr    LocationDesc  \
# 0           2011     2011           AL         Alabama
# 1           2011     2011           AL         Alabama
# 2           2011     2011           AL         Alabama
# 3           2011     2011           AL         Alabama
# 4           2011     2011           AL         Alabama
# ...          ...      ...          ...             ...
# 53387       2016     2016           VI  Virgin Islands
# 53388       2016     2016           VI  Virgin Islands
# 53389       2016     2016           VI  Virgin Islands
# 53390       2016     2016           VI  Virgin Islands
# 53391       2016     2016           VI  Virgin Islands
#
#                                        Datasource                    Class  \
# 0      Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 1      Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 2      Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 3      Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 4      Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# ...                                           ...                      ...
# 53387  Behavioral Risk Factor Surveillance System        Physical Activity
# 53388  Behavioral Risk Factor Surveillance System        Physical Activity
# 53389  Behavioral Risk Factor Surveillance System        Physical Activity
# 53390  Behavioral Risk Factor Surveillance System        Physical Activity
# 53391  Behavioral Risk Factor Surveillance System        Physical Activity
#
#                               Topic  \
# 0           Obesity / Weight Status
# 1           Obesity / Weight Status
# 2           Obesity / Weight Status
# 3           Obesity / Weight Status
# 4           Obesity / Weight Status
# ...                             ...
# 53387  Physical Activity - Behavior
# 53388  Physical Activity - Behavior
# 53389  Physical Activity - Behavior
# 53390  Physical Activity - Behavior
# 53391  Physical Activity - Behavior
#
#                                                 Question  Data_Value_Unit  \
# 0      Percent of adults aged 18 years and older who ...              NaN
# 1      Percent of adults aged 18 years and older who ...              NaN
# 2      Percent of adults aged 18 years and older who ...              NaN
# 3      Percent of adults aged 18 years and older who ...              NaN
# 4      Percent of adults aged 18 years and older who ...              NaN
# ...                                                  ...              ...
# 53387  Percent of adults who engage in no leisure-tim...              NaN
# 53388  Percent of adults who engage in no leisure-tim...              NaN
# 53389  Percent of adults who engage in no leisure-tim...              NaN
# 53390  Percent of adults who engage in no leisure-tim...              NaN
# 53391  Percent of adults who engage in no leisure-tim...              NaN
#
#       Data_Value_Type  ...                              GeoLocation  ClassID  \
# 0               Value  ...  (32.84057112200048, -86.63186076199969)      OWS
# 1               Value  ...  (32.84057112200048, -86.63186076199969)      OWS
# 2               Value  ...  (32.84057112200048, -86.63186076199969)      OWS
# 3               Value  ...  (32.84057112200048, -86.63186076199969)      OWS
# 4               Value  ...  (32.84057112200048, -86.63186076199969)      OWS
# ...               ...  ...                                      ...      ...
# 53387           Value  ...                  (18.335765, -64.896335)       PA
# 53388           Value  ...                  (18.335765, -64.896335)       PA
# 53389           Value  ...                  (18.335765, -64.896335)       PA
# 53390           Value  ...                  (18.335765, -64.896335)       PA
# 53391           Value  ...                  (18.335765, -64.896335)       PA
#
#       TopicID QuestionID  DataValueTypeID  LocationID  \
# 0        OWS1       Q036            VALUE           1
# 1        OWS1       Q036            VALUE           1
# 2        OWS1       Q036            VALUE           1
# 3        OWS1       Q036            VALUE           1
# 4        OWS1       Q036            VALUE           1
# ...       ...        ...              ...         ...
# 53387     PA1       Q047            VALUE          78
# 53388     PA1       Q047            VALUE          78
# 53389     PA1       Q047            VALUE          78
# 53390     PA1       Q047            VALUE          78
# 53391     PA1       Q047            VALUE          78
#
#        StratificationCategory1                Stratification1  \
# 0                        Total                          Total
# 1                       Gender                           Male
# 2                       Gender                         Female
# 3                    Education          Less than high school
# 4                    Education           High school graduate
# ...                        ...                            ...
# 53387           Race/Ethnicity                          Asian
# 53388           Race/Ethnicity      Hawaiian/Pacific Islander
# 53389           Race/Ethnicity  American Indian/Alaska Native
# 53390           Race/Ethnicity                2 or more races
# 53391           Race/Ethnicity                          Other
#
#       StratificationCategoryId1 StratificationID1
# 0                           OVR           OVERALL
# 1                           GEN              MALE
# 2                           GEN            FEMALE
# 3                           EDU             EDUHS
# 4                           EDU         EDUHSGRAD
# ...                         ...               ...
# 53387                      RACE           RACEASN
# 53388                      RACE           RACEHPI
# 53389                      RACE           RACENAA
# 53390                      RACE         RACE2PLUS
# 53391                      RACE           RACEOTH
#
# [53392 rows x 33 columns]

# %%
df.QuestionID.value_counts()
# Out:
# Q036    8960
# Q037    8960
# Q047    8932
# Q019    4424
# Q046    4424
# Q043    4424
# Q044    4424
# Q045    4424
# Q018    4420
# Name: QuestionID, dtype: int64
